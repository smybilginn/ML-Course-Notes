# %% [markdown]
# <a href="https://colab.research.google.com/github/smybilginn/ML-Course-Notes/blob/main/makine_ogrenmesi_ders_notlari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BÖLÜM 1**
#
# # **MAKİNE ÖĞRENMESİ TEMEL KAVRAMLAR**
# ##1. **Makineler Nasıl Öğrenir?**
# Makineler veriye dayalı bir öğrenme yöntemi içerirler, ayrıca makineler hatalardan, tecrübelerden, deneyimlerden öğrenirler.
#
# ##2. **Makinelerde Öğrenme Kavramı Nedir?**
# Modellerin (Karar ağaçları,Random Forest,svm,Logistic Regression) belirli bir görevi gerçekleştirmek için gerekli olan parametrelerinin veya ağırlıklarının veriye dayalı olarak ayarlanması veya optimize edilmesini ifade etmektedir.
#
# ##3. **Makine Öğrenmesi ve Geleneksel Programlama**
# - **Programlama Yaklaşımı:** Geleneksel programlamada bir yazılım geliştirici bir görevi gerçekleştirmek için adım adım algoritma tasarlar ve kodlar.Örneğin kedi ve köpek sınıflandırıcı yapıyorsa geleneksel programlamada satır satır gerekli kodları yazar -eğer kuruk uzunsa köpek olsun, kuyruk kısa ise kedi olsun- gibi farklı kurallarla geleneksel programlama yapar. **Makine öğrenmesi**nde ise bir model belirli görevi gerçekleştirmek için eğitilir ve veriye dayalı olarak bu görevi öğrenir. Sonrasında modelin davranışı veriye ve deyime dayalı olarak şekillenir ancak tam olarak nasıl çalıştığı insanlar tarafından belirlenemez. Yani geleneksel programlamaya göre sıfırdan adım adım bir algoritma tasarlanmaz veriye dayalı eğitim gerçekleştirilir.
# - **Kural Tabanlı Bilgi:** Geleneksel programlamada yazılım geliştirici belirli kuralları açıkça tanımlar **makine öğrenmesi**nde model veriye dayalı olarak kalıpları belirler(yani desenleri tanımlar) bu kalıplar üzerinde öğrenme işlemini gerleştiririr.
#
#
# - **Esneklik ve Genelleme:** Geleneksel programlama da genel olarak bir problem için özel olarak tasarlanmıştır ve bu prolem dışında kullanılmaz. Örneğin kedi ile köpek ayrımı için farklı bir algoritma, insan ve araba ayrımı için farklı bir algoritma, kanser teşhisi için farklı bir algoritma yazılır ve bunlar birbiri yerine kullanılmaz. **Makine öğrenmesi**nde ise modeller genellikle belli bir problem alanında eğitilir ancak eğitim verisi geniş bir yelpazeyi temsil edebiliyorsa model genellikle bu problem alanı dışında da iyi performans gösterebilir.
# - **Değişkenlik ve Adaptasyon:** Geleneksel programlama genellikle sabit ve değişmezdir ama **makine öğrenmesi**nde modeller esnektir, adaptif olabilir yeni veriler geldikçe model kolaylıkla eğitilebilir ve yeni bilgilere uyum sağlayabilir.
#
# # **Makine Öğrenmesi Yöntemleri**
# ##1. **Makine Öğrenmesi Terminolojisi**
# ### 1. **Veri Kümesi (Dataset)**
# Makine öğrenimi algoritmalarının eğitilmesi ve değerlendirilmesi için kullanılan veri örneklerinin toplamıdır. Dataset içerisinde genellikle input öznitelikleri ve bunlara karşılık gelen target(hedef) değerleri içerirler.
#
# ### 2. **Öznitelik (Features)**
# Veri noktalarını tanımlayan öz niteliklerdir.Makine öğrenimi algoritmalarının modellenmesi ve tahmin yapması için kullanılan değişkenlerdir.
#
# ### 3. **Etiketler (Labels)**
# Gözetimli öğrenme problemlerinde hedef değişkenler olarak adlandırılırlar. Bir veri örneğinin etiketi özelliklere karşılık gelen gerçek çıktı veya sınıfı temsil etmektedir.
#
# ### 4. **Model**
# Makşne öğrenimi algoritması tarafından eğitilen ve veriler arasındaki örüntüleri yakalamak için kullanılan matematiksel bir yapıdır. Model girdi verilerini alır ve belirli bir çıktıyı üretir.
#
# ### 5. **Eğitim (Training)**
# Bir makine öğrenimi modelinin veri kümesi üzerindeki örneklerle eğitilmesi sürecidir. Eğitim süreci, makine öğrenmesi modelinin içinde bulunan parametrelerin ayarlanması optimimze edilmesidir. Model eğitim sayesinde model üzerindeki örüntüleri tanıyabilir ve genelleme yapabilir hale gelebilir.
#
# ### 6. **Doğrulama (Validation)**
# Eğitim sürecinde modelin performansını değerlendirir ve hipreparametrelerin parametrelerin ayarlanmasına yardımcı olmak için ayrılan bir veri kümesidir.
#
# ### 7. **Test**
# Modelin eğitim ve doğrulama dışındakiş gerçek dünya performansını değerlendirmesi için ayrılan veri kümesidir.
#
# ### 8. **Sınıflandırma (Classification)**
# Bir veri noktasını bir veya daha fazla sınıfa atayan bir tahmin problemidir.
# Sınıflandrıma problemlerindeki çıktılar genellikle kategorik etiketlerdir.
#
# ### 9. **Regresyon (Regression)**
# Bir çıktı değişkeninin sürekli bir değerini tahmin etmey açalışan bir tahmin problemidir. Çıktılar sayısal değerlerdir.
#
# ### 10. **Öğrenme Algoritmaları (Learning Algorithms)**
# Veri üzerinden örüntüleri keşfetmek ve modellemek için kullanılan matematiksel ve istatistiksel tekniklerdir. Gözetimli, gözetimsiz ve takviyeli öğrenme gibi farklı kategoriler mevcuttur.
#
# ### 11. **Öznitelik Mühendisliği (Feature Engineering)**
#
#
# ### 12. **Hiperparametler (Hyperparameters)**
# Modelin yapılandırmasını ve eğitim sürecini kontrol eden parametrelerdir.
#
# ### 13. **Overfitting ve Underfitting**
# Modelin eğitim verilerine aşırı uyum sağlamasına overfitting denir. Yani aslında *ezberleme*. Modelin eğitim verilerine yeterince uyum sağlayamaması yani *öğrenememe* durumu underfittig olarak adlandırılır.
#
# ### 14. **Cross-Validation (Çağraz Doğrulama)**
# Modelin performansını değerlendirmek için kullanılan bir tekniktir. Veri kümesi birden fazla alt kümeye bölünür ve her bir alt küme sırasıyla eğitim ve doğrulama için kullanılır. Bu sayede modelin genelleme yeteneği daha güvenilir bir şekilde değerlendirilmiş olur. Test aşamasında kullanılan bir kavramdır.
#
# ### 15. **Derin Öğrenme (Deep Learning)**
# Yapay sinir ağları gibi karmaşık ve çok katmanlı modellerin kullanıldığı makine öğrenmesinin bir alt dalıdır. Derin öğrenme büyük veri setleri üzerinde karmaşık örüntüleri öğrenmek için etkili bir yaklaşım sunmaktadır.
#
#
#
# ![Makine Öğrenmesi Türleri](https://i0.wp.com/www.savasanadam.com/wp-content/uploads/2022/02/makine-ogrenmesi-turleri.jpg?resize=640%2C325&ssl=1)
#
#
#
# #2. **Makine Öğrenmesi Süreci, Uygulamaları ve Araçları**
# ### 1. **Makine Öğrenmesi Süreci**
# - Verilerin toplanması, düzenlenmesi, ve bölünmesi
# - Makine öğrenmesi modelinin seçilmesi
# - Modelin *train* edilmesi
# - Sonuçların değerlendirilmesi
# - Hiperparametre ayarlaması
# - Modelin hizmete sunulması
#
#
# ### 2. **Makine Öğrenmesi Uygulamaları**
# - Tıp ve sağlık
# - Finans
# - Perakende ve pazarlama
# - Ulaşım ve lojistik
# - Güvenlik ve siber güvenlik
# - Sınır güvenliği
# - Robotik
# - Enerji planlaması ve verimlilik
#
# ### 2. **Makine Öğrenmesi Araçları**
#
#
# ![Makine Öğrenmesi Türleri](https://cdn.botpenguin.com/assets/website/Screenshot_2024_01_09_at_1_05_48_PM_710b471834.webp)
#
#
# ---
# **BÖLÜM 2**
#
#
# # **Makine Öğrenmesi için Veri Ön İşleme**
# ##1. **Veri Nedir?**
# Veri bilgi taşıyan ve anlam ifade eden ögelerin toplamıdır.
# Genellikle sayılar, metin, görsel veya diğer formdaki bilgisari içerir.
#
#
# ![Java Data Types](https://www.scientecheasy.com/wp-content/uploads/2020/06/java-data-types.png)
#
#
# ##2. **Veri Tipleri**
# ![Types of Data](https://panintelligence.com/wp-content/uploads/2024/09/Types-of-data.webp)
#
#
# ## 🔶 **Nitel (Qualitative) Veriler**
#
# Bu tür veriler sayısal değildir, **kategorilere** ayrılır.
#
# ### 1. **Nominal (Adlandırılmış) Veri**
# - **Tanım:** Sadece **isimlendirme** amacı taşır. Sıralama yoktur.
# - **Özellik:** Sayısal anlam taşımaz.
# - **Örnekler:**
#   - Cinsiyet: Erkek, Kadın
#   - Renkler: Kırmızı, Mavi, Yeşil
#   - Şehir isimleri: İstanbul, Ankara, İzmir
#
# ### 2. **Ordinal (Sıralı) Veri**
# - **Tanım:** Kategoriler **sıralıdır**, ama aralarındaki fark ölçülemez.
# - **Örnekler:**
#   - Memnuniyet düzeyi: Çok memnun, Memnun, Kararsız, Memnun değil
#   - Eğitim seviyesi: İlkokul < Ortaokul < Lise < Üniversite
#   - Yarışma sıralaması: 1., 2., 3.
#
#
# ## 🔷 **Nicel (Quantitative) Veriler**
#
# Bu tür veriler **sayısaldır**, ölçülebilir.
#
# ### 3. **Interval (Aralıklı) Veri**
# - **Tanım:** Sayılar arasındaki fark anlamlıdır, ama **mutlak sıfır** yoktur.
# - **Özellik:** Toplama ve çıkarma yapılabilir, ama oran alınamaz.
# - **Örnekler:**
#   - Sıcaklık (°C): 20°C – 10°C = 10°C fark var ama 20°C "iki kat sıcak" değildir.
#   - Takvim yılları: 2000, 2020
#
# ### 4. **Ratio (Oranlı) Veri**
# - **Tanım:** Sayılar arasında anlamlı fark ve **mutlak sıfır** noktası vardır.
# - **Özellik:** Her türlü matematiksel işlem yapılabilir (toplama, çıkarma, çarpma, bölme).
# - **Örnekler:**
#   - Ağırlık: 10 kg, 20 kg → 20 kg = 2 katı
#   - Yaş: 25 yaş, 50 yaş → 50 yaş 2 katıdır
#   - Gelir: 5000 TL, 10000 TL
#
#
# ##3. **Veri Ön İşleme**
# Veri setini hazırlama sürecidir.
# Veri ön işleme aşamaları genellikle şunları içerir:
# - **Veri Temizleme**: Veri seti içerisindeki hataların, tutarsızlıkların ele alınarak düzeltilmesi.
# - **Veri Standardizasyonu**: Veri setindeki özelliklerin farklı ölçeklerde olması durumunda özellikleri aynı ölçek veya aralıklara getirme işlemidir.
# - **Öznitelik Seçimi**: Analiz veya modelleme için gereksiz veya etkisiz olan öznitelikleri veriden çıkarma işlemi.
# - **Verinin Dönüşümü**: Veri setindeki özellikleri veya değerleri farklı bir formata dönüştürme işlemi. Örneğin kategorik verilerin sayısal verilere dönüştürülmesi.
# - **Aykırı Değerlerin İşlenmesi**: Veri setindeki aykırı değerlerin tespit edilmesi ve uygun şekilde ele alınması işlemidir.
#
# ### **Veri Temizleme Neden Gerekli?**
# - **Doğruluk**: Verideki hatalar veya yanlış girişler analiz sonuçlarını bozabilir. Temiz veri, daha doğru sonuçlar sağlar.
# - **Tutarlılık**: Aynı bilgilerin farklı formatlarda veya isimlerle yer alması karışıklığa neden olabilir. Tutarlılık sağlamak, verinin bütünlüğünü korur.
# - **Eksik Veri Problemi**: Eksik veriler analizleri yanıltabilir. Bu tür verilerin tespiti ve uygun şekilde işlenmesi gereklidir (örneğin: doldurma, çıkarma).
# - **Aykırı Değerler**: Normalden çok farklı olan değerler analiz sonuçlarını ciddi şekilde etkileyebilir. Bu değerlerin incelenmesi ve gerekirse temizlenmesi gerekir.
# - **Standatlaştırma**: Verilerin ortak bir biçime (örneğin tarih formatları, ölçü birimleri) getirilmesi analizlerin sağlıklı yapılabilmesi için şarttır.
#
# ### **Veri Temizleme Yöntemleri**
# - **Kayıp Veri Problemi**: Eksik verilerin tespit edilmesi ve uygun bir şekilde doldurulması işlemidir.
# - **Tutarsız Veriyi Düzeltme**: Veri setinin içerisinde bulunan tutarsızlıkların tespit edilmesi ve düzeltilmesi işlemidir.
# - **Yinelenen Verilerin Silinmesi**: Veri setindeki tekrarlayan verilerin tespit edilmesi ve bunların ortadan kaldırılması işlemidir.
# - **Gereksiz Sütunların Silinmesi**: Veri setinde bulunan aynı bilgiyi ifade eden bizim modelimizde kullanmayacağımız sütunların silinmesi işlemidir.
#
# ### **Veri Kodlaması**
# Veri kodlaması kategorik (nominal veya ordinal) verileri sayısal değerlere dönüştürme işlemidir.
# Bu dönüşüm, makine öğrenimi algoritmaları gibi birçok analiz yöntemi için gereklidir, çünkü algoritmalar genellikle sayısal verilerle çalışır.
# Veri kodlamasının iki ana türü vardır:
# - Nominal Kodlama
# - Ordinal Kodlama
#
# ![Nominal vs Ordinal](https://www.researchgate.net/profile/Dahouda-Mwamba/publication/353857384/figure/fig2/AS:1056153375100929@1628817995252/Categorical-data-Nominal-vs-ordinal-scale.ppm)
#
#
#
# # **Öznitelik Mühendisliği (Feature Engineering)**
#
# ##1. **Öznitelik Nedir?**
# Öznitelik (feature), bir veri örneğini tanımlayan veya açıklayan herhangi bir özelliktir.
# Öznitelikler, veri setindeki her bir gözlemin bir parçasını oluşturan ölçülebilir veya gözlemlenebilir özelliklerdir.
# Öznitelikler, veri setinin her bir sütununu temsil eder.
#
#
# ##2. **Öznitelik Mühendisliği (Feature Engineering)**
# Veri bilimi ve makine öğrenimi alanında kullanılan bir tekniktir ve veri setindeki öz nitelikleri (features) optimize etmek veya yeni öz nitelikler oluşturmak için yapılan işlemleri ifade eder.
#
#
# ![Feature Engineering](https://media.geeksforgeeks.org/wp-content/uploads/20250701114435618562/feature-engineering.webp)
#
#
# ##3. **Öznitelik Mühendisliği (Feature Engineering) Önemi**
# - Model performansını artırma. İyi tasarlanmış öznitelikler modelin daha doğru ve güvenilir tahminler yapmasına yardımcı olacaktır.
# - Boyut Azaltma. Veri setindeki gereksiz veya fazla sayıdaki özniteliklerin çıkarılması veya birleştirilmesi modelin karmaşıklığını azaltıcaktır.
# - Hesaplama maliyetini azaltma.
#
# ##4. **Öznitelik Seçimi (Feature Selection)**
# Öznitelik seçimi (feature selection), veri setinde bulunan öznitelikler arasından en önemli veya en bilgilendirici olanları seçme veya belirleme sürecidir.
# Bu süreçte veri setinde bulunan gereksiz, tekrarlayan veya düşük özniteliklerin tanımlanması ve çıkarılması hedeflenir.
# Amacı, modelin performansını artırmak, karmaşıklığı azaltmak ve aşırı uydurmayı (over fitting) engellemektir.
#
# ##5. **Öznitelik Seçimi Yöntemleri**
# - İnformasyon tabanlı yöntemler
# - Wrapper yöntemler
# - Gömülü yüntemler
# - Filter yöntemler
#
# ##6. **Öznitelik Çıkarma (Feature Extraction)**
# Feature extraction, veri setindeki özniteliklerin temsilini değiştirme veya dönüştürme sürecidir. Örneğin doğum tarihi verisini yaş verisine dönüştürme.
# Feature extraction, veri boyutunu azaltarak gereksiz bilgiyi çıkarır ve verinin daha anlamlı bir şekilde temsil edilmesini sağlayarak model performansını artırabilir.
#
# ![Feature Extraction](https://miro.medium.com/v2/0*sQzmiOf8Yb_18HX1.png)
#
#
# ##7. **Öznitelik Çıkarma (Feature Extraction) Önemi**
# - Model performası artırma. Doğru şekilde yapıldığında modelin daha iyi öğrenmesini sağlar ve daha doğru tahminler yapmasına yardımcı olur.
# - Boyut azaltma.
# - Gereksiz bilgiyi ortadan kaldırma.
#
# ##8. **Öznitelik Çıkarma (Feature Extraction) Yöntemleri**
#
# - Principle Component Analysis (PCA)
#
#
# ![PCA](https://towardsdatascience.com/wp-content/uploads/2022/02/1QinDfRawRskupf4mU5bYSA.png)
#
#
# - Linear Discriminant Analysis (LDA)
#
#
# ![LDA](https://lh3.googleusercontent.com/proxy/BGSO9eNu30Lw4yJBAC2NEkuzKxg0jIjrOZnt3B2TEeZskG3eRX8fAZGT-hNwneboONk6V_bds62TVksvSER2B1XDYfnDLBWhYb_6WMqeh9BrCjNK)
#
#
# - Autoencoders
#
#
# ![Autoencoders](https://miro.medium.com/v2/resize:fit:1400/1*44eDEuZBEsmG_TCAKRI3Kw@2x.png)
#
#
# ##6. **Veri Normalizasyonu ve Standardizasyonu**
# Veri normalizasyonu ve standardizasyonu, veri özniteliklerinin farklı ölçeklere veya dağılımlara sahip olması durumunda bunları belirli bir standart forma dönüştürmek için kullanılan yöntemlerdir.
#
#
# ### 🔹 1. **Normalizasyon (Normalization)**
# Verilerin belirli bir aralığa (genellikle 0 ile 1) dönüştürülmesidir. Özellikle mesafeye dayalı algoritmalarda (KNN, K-Means gibi) kullanılır.
#
# **Formül (Min-Max Normalizasyonu):**
#
# ![Normalizayon](https://wallstreetmojocms.recurpro.in/uploads/Normalization_Formula_5c52428d4b.jpg)
#
# **Ne zaman kullanılır?**
# - Farklı ölçeklerdeki veriler varsa
# - Veri dağılımı normal değilse
# - KNN, K-Means gibi algoritmalarda
#
#
# ### 🔹 2. **Standardizasyon (Standardization)**
#
# Verilerin ortalaması 0, standart sapması 1 olacak şekilde dönüştürülmesidir. Özellikle dağılımı normal olan verilerde tercih edilir.
#
# **Formül (Z-Score Standardizasyonu):**
#
# ![Standardizasyon](https://iblog.milliyet.com.tr/imgroot/blogv7/Blog333/2013/05/03/32/410367-3-4-d40b6.jpg)
#
# **Ne zaman kullanılır?**
# - Veriler normal dağılıma yakınsa
# - SVM, Lojistik Regresyon, PCA gibi algoritmalarda
#
#
# # **Veri Tipleri ve Dönüşümleri**
# ##**Ayrık ve Sürekli Veri Ayırma**
# Ayrı (discrete) ve sürekli (continuous) veri, istatistik ve veri bilimi alanlarında temel olarak ikş farklı veri tipini ifade eder.
#
# Veri bilimi ve istatistikte veriler genellikle **sayısal** (nicel) olarak sınıflandırılır. Sayısal veriler iki ana kategoriye ayrılır:
#
#
# ### 🔸 1. **Ayrık Veri (Discrete Data)**
#
# Ayrık veriler, **sadece belirli değerleri** alabilen, sayılabilen verilerdir. Genellikle **tam sayılardır**.
#
# **Özellikleri:**
# - Sayılabilir (kategorik değil, ama sınırlı sayıda değer alır)
# - Genellikle kesikli (integer) değerlerden oluşur
# - Aradaki değerler anlamsız veya mümkün değildir
#
# **Örnekler:**
# - Sınıftaki öğrenci sayısı → 25 öğrenci
# - Bir zarın atılması sonucu → 1, 2, 3, 4, 5, 6
# - Satılan ürün adedi → 0, 1, 2, ...
#
#
#
#
# ### 🔹 2. **Sürekli Veri (Continuous Data)**
#
# Sürekli veriler, **herhangi bir aralıktaki sonsuz sayıda değeri** alabilir. Genellikle **ölçülebilir** büyüklüklerdir.
#
# **Özellikleri:**
# - Sonsuz hassasiyetle ölçülebilir
# - Ondalıklı değerler alabilir
# - Aralıklı ve kesintisizdir
#
# **Örnekler:**
# - Boy uzunluğu → 175.4 cm
# - Ağırlık → 68.9 kg
# - Zaman → 12.35 saniye
# - Sıcaklık → 36.7 °C
#
#
# ### 🧠 Kısa Kıyaslama
#
# - Ayrık veri → **Sayılır** (kaç kişi, kaç ürün)
# - Sürekli veri → **Ölçülür** (kaç cm, kaç kg)
#
#
# ### ✅ Not:
#
# - Sürekli veriler, istenirse belirli aralıklara bölünerek ayrık hale getirilebilir. Örneğin: yaş → 0-10, 11-20 gibi sınıflara ayrıldığında **kategorik ayrık** hale gelir.
#
# ![Ayrık vs Sürekli](file:///C:/Users/LENOVO/Downloads/-Discrete-Vs-Continuous-.webp)
#
#
# ##**Veri Bölme**
# Veri bölme, bir veri setini eğitim, doğrulama validation) ve test (test) kümeleri olarak üçe veya daha fazla parçaya ayırmak anlamına gelir.
# Genellikle, veri setinin büyük bir kısmı modelin eğitimi için kullanılırken geri kalan kısmı modelin doğrulaması ve test edilmesi için kullanılır.
#
# Örneğin ML veri sayımız 1000 ise %80 eğitim, %10,10 ise doğrulama ve test için kullanılabilir. DL için ise veri sayısı örneğin 10000 ise %90 eğitim %5,5 dpğrulama ve test için kullanılabilir.
#
#
#
# ##**Veri Bölmenin Önemi**
# - Veri bölmenin makine öğrenimi açısından önemi
#   - Model persormansının doğru değerlendirilmesi
#   -Aşırı uydurmanın önlenmesi
#   - Parametre ayarının ve Model seçiminin yapılması
#
#
# ##**Dengesiz Veri İşleme**
# Makine öğrenmesinde dengesiz veri, farklı sınıflara ait örneklerin sayısal olarak büyük farklılıklar gösterdiği durumlarda ortaya çıkar.
# Örneğin, bir sınıfın örnek sayısı diğerlerine göre çok daha fazlaysa bu dengesiz veri problemi olarak kabul edilir.
# Dengesiz veri, modelin eğitimini ve performansını olumsuz yönde etkiler çünkü nadir sınıfların öğrenilmesi zorlaşabilir ve modelin bu sınıfları tanımlaması daha düşük olabilir.
#
#
# ##**Dengesiz Veri İşleme Yöntemleri**
# - Oversampling (Aşırı Örnekleme)
# - Undersampling (Yetersiz Örnekleme)
# - Synthetic Sampling (Sentetik Örnekleme)
#
#
# ![Veri İsleme Yöntem](https://media.springernature.com/lw1200/springer-static/image/art%3A10.1007%2Fs10115-022-01772-8/MediaObjects/10115_2022_1772_Fig1_HTML.png)
#
#
# #**Aykırı Değer İşleme**
# ##**Aykırı Değer (Outlier) Nedir?**
# Aykırı değer (outlier), genel trendden önemli ölçüde farklı olan ve genellikle diğer veri noktalarından uzakta bulunan bir veri noktasıdır.
# Makine öğrenmesi bağlamında, aykırı değerler genellikle modelin yanlış eğitilmesine veya yanıltılmasına neden olabilir.
#
#
# ![outlier](https://ouzhang.me/blog/outlier-series/sidebar-featured.jpg)
#
#
# ##**Aykırı Değer Tespiti Önemi**
# -Outliers modelin genelleme yeteneğini azaltır ve modelimizin accuracyni düşürür.
# - Modelin hassasiyetini artırır. Outliersların çıkarılması modelin daha güvenilir tahmin yapmasını sağlar.
# - Modelin yorumlanabilirliğini artırır.
#
#
# ##**Aykırı Değer Tespit Etme Yöntemleri**
# - **Standart Sapma Yaklaşımı**: Bu yöntemde, verilerin ortalamasına (mean) olan uzaklıklarına bakılır.Veri noktaları, belirli bir standart sapma (genellikle ±2 veya ±3) dışına çıkıyorsa aykırı değer olarak kabul edilir.
#
# ![SD](https://walkermathcollegeprep.weebly.com/uploads/4/5/8/1/45815247/4737583.jpg?1429747198)
#
#
#
# - **Box Plot (Kutu Grafiği) Yöntemi**: İstatistiksel olarak verinin dağılımını görselleştirerek aykırı değerleri tespit eder.
#
# ![Box Plot](https://pieriantraining.com/wp-content/uploads/sites/2/2022/07/Untitled-2-1024x507.jpg)
#
#
# - **Z-Skoru Yaklaşımı**: Her bir verinin, ortalamadan kaç standart sapma uzaklıkta olduğunu ölçer.
#
# ![Z-Score](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSkP2VK112609u7_-GKy03D-8Fnpe5AB41vUQ&s)
#
#
# - **LOF (Local Outlier Factor)**: Makine öğrenmesi temelli, yoğunluk tabanlı bir aykırı değer tespit yöntemidir.
#
#
# ![LOF](https://miro.medium.com/v2/0*W4tTJqWKQ-sEGPZK.png)
#
#
# ---
# **BÖLÜM 3**
#
#
# #**Makine Öğrenmesi için Temel Matematik**
# ##**Lineer Cebir**
# Lineer cebir, makine öğrenmesinin temel taşlarından biridir.
# Özellikle matrisler, vektörler ve matris işlemleri makine öğrenmesi algoritmalarının pek çoğunda kullanılır.
# Örneğin, model parametrelerinin matris formunda ifade edilmesi, öznitelik vektörlerinin işlenmesi ve boyut indirgeme tekbikleri gibi.
#
#
# ##**Skaler ve Vektör**
# ###**Skaler (Scalar)**
# - Skaler, büyüklüğü(magnitude) belirtilen ve yalnızca bir sayıdan oluşan matematiksel bir nesnedir. Yani, sadece büyüklüğü vardır ve bir yöne veya konuma sahip değildir.
# - Bir otomobilin hızı, bir kişinin yaşı veya bir oda sıcaklığı birer skaler değerdir.
#
#
# ###**Vektör (Vector)**
# - Vektör, hem büyüklüğü (magnitude) hem de yönü (direction) belirten matematiksel bir nesnedir.Bir başlangıç noktasından bir bitiş noktasına yönelen bir ok olarak düşünülebilir.
# - Bir otomobilin hızı ve yönü birer vektördür. Bir kuvvetin uygulandığı yön ve şiddeti de bir vektör olarak ifade edilebilir.
#
# ##**Skaler ve Vektör Çarpımı**
# - Bir vektörün her elemanının bir skaler sayıyla çarpılması işlemidir.
#
# ##**Matrisler**
# - Matrisler, sayılar kümesinin satır ve sütunlarla düzenlenmiş bir düzlem tablosudur.
#
#
# ![Matrix](https://miro.medium.com/v2/1*HrBk8CLYR_0GHsZNFUBs4A.png)
#
#
# ##**Matris İşlemleri**
# - Skaler-Matris Çarpımı
# - Matris-Matris Toplama
# - Matris-Matris Çıkarma
# - Matris-Matris Çarpımı
# - Vektör-Matris İşlemleri
# - Transpoze
# - Ters Matris
#
#
# ##**Lineer Denklemler**
# -Linner denklem, içinde yalnızca birinci dereceden terimlerin bulunduğu bir denklem sistemidir.
# - Bu denklemler, bilinmeyen değişkenlerin doğrusal olarak ifade edildiği denklemlerdir.
# -Makine öğrenmesi bağlamında, lineer denklemler genellikle modelin temelini oluşturur.
# - Özellikle regresyon analizi ve sınıflandırma gibi temel makine öğrenmesi problemlerinde lineer modeller sıklıkla kullanılır.
#
#
# ![Lineer Denklem](https://d138zd1ktt9iqe.cloudfront.net/media/seo_landing_files/the-standard-form-of-a-linear-equation-1612342342.png)
#
#
#
# ##**Kalkülüs**
# **Türev**
#
#
# Türev, bir fonksiyonun belirli bir noktasındaki anlık değişim oranını ifade eder.
# Özellikle gradyan inişi (LR ve DL algoritmalarının hepsinde kullanılır) gibi optimizasyon teknikleri, bir fonksiyonun türevini kullanarak en uygun parametre değerlerini bulmaya çalışır. Modelin kayıp fonksiyonunun (loss function) türevi, parametre güncellemelerinde bir rehber olarak kullanılır.
#
#
# **İntegral**
#
#
# İntegral, bir fonksiyonun belirli bir aralıktaki alanını ifade eder.
# İntegral, bir fonksiyonun toplamını almak için kullanılır ve belirli bir aralıktaki sonsuz küçük parçaların toplamını hesaplamak için integral işareti kullanılır.
#
#
# ![Türev vs İntegral](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsDrW4R-KMx1KNafuNzk2q0s5Ra6Zp6sQnGg&s)
#
#
# ##**Olasılık ve İstatistik**
# ###**Olasılık ve İstatistik Nedir?**
# - Olasılık, belirszilik altında olayların olasılığını ve bu olayların matematiksel modellerini inceleyen bir alandır. Bir olayın gerçekleşme olasılığını sayısal olarak ifade eder.
# - İstatistik; veri toplama, analiz etme, yorumlama ve sonuç çıkarma süreçlerini inceleyen bir alandır. Bu süreçler, veri setlerinden anlamlı bilgiler çıkarılmasına ve karar verme süreçlerine destek sağlar.
#
#
# ###**Olasılık Temel Kavramları**
# - Olay (Event)
# - Örnek Uzay (Sample Space)
# - Koşullu olasılık (Conditional Probability)
#
#
#
# ###**Olasılıksal Dağılımlar**
# - Normal Dağılım (Gauss Dağılımı)
# - Bernoulli Dağılımı
# - Binom Dağılımı
# - Poisson Dağılımı
#
#
# ![Dagılımlar](https://miro.medium.com/v2/resize:fit:1400/1*tpb1u0qRrzNYBxSOFiaDXw.png)
#
#
# ###**Koşullu Olasılık**
# Koşullu olasılık, bir olayın gerçekleşme durumuna bağlı olarak gerçekleşme olasılığını ifade eder.
#
#
# ![KO](https://i.sstatic.net/93Y1t.png)
#
#
# ###**Temel İstatistiksel Özellikler**
# - **Ortalama (Mean)**: Bir veri setindeki değerlerin toplamının veri sayısına bölümüdür. Veri setinin merkezi eğilimini gösterir.
# - **Medyan (Median)**: Bir listedeki ortadaki sayıyı ifade eder.
# - **Mod (Mode)**: Bir veriseti içerisinde hangi değerin kaç tane bulunduğunu ifade eder.
# - **Varyans (Variance)**: Bir verisetindeki değerlerin ortalamadan ne kadar uzak olduğunun ölçüsüdür. Değişkenliği ifade eder.
#
# - **Standart Sapma (Standart Deviation)**: Verisetindeki değerlerin ortalamadan ne kadar saptığı hakkında bilgi verir. Varyansın karekökü alınarak hesaplanır.
#
# ---
# **BÖLÜM 4**
#
#
# #**Gözetimli Öğrenme**
# ##**Gözetimli Öğrenme (Supervised Learning) Nedir?**
# Gözetimli öğrenme, eğitim verilerinde girdi(features) ve çıktı (label) arasındaki ilişkiyi öğrenmeyi amaçlayan bir makine öğrenmesi yaklaşımıdır.
# Bu tür öğrenme genellikle **etiketlenmiş veri** ile gerçekleştirilir, yani her girdiye karşılık gelen çıktı etiketi bulunur.
# Gözetimli öğrenmenin ana adımları şunlardır:
# - Veri toplama ve hazırlığı
# - Model seçimi ve eğitimi
# - Model değerlendirmesi
# - Model ayarlaması ve hiperparametre optimizasyonu
#
#
# Gözetimli öğrenme, sınıflandırma ve regresyon gibi çeşitli problemleri çözmek için kullanılabilir.
# Örnek olarak; hastalık teşhisi, müşteri tercihlerini tahmin etme, pazar segmentasyonu ve hisse senedi fiyatlarını tahmin etme bulunmaktadır.
#
#
# ![Supervised Learning](https://www.savasanadam.com/wp-content/uploads/2022/02/gozetimli-ogrenme-1024x499.jpg)
#
#
# ##**Gözetimli Öğrenme Algoritmaları**
# - Sınıflandırma Algoritmaları (Classification Algorithms)
#   - K-En Yakın Komşu (K-Nearest Neighbors **KNN**)
#   - Rasgele Orman (Random Forest **RF**)
#   - Logistic Regresyon (Logistic Regression **LR**)
#   - Destek Vektör Makinesi (Support Vector Machine **SVM**)
#   - Naive Bayes (Naive Bayes Classifier **NB**)
# - Regresyon Algoritmaları (Regression Algorithms)
#   - Lineer Regresyon (Linear Regression **LR**)
#   - Çoklu Lineer Regresyon (Multiple Linear Regression **MLR**)
#   - Polinom Regresyon (Polynomial Regression **PR**)
#
#
# ##**K-En Yakın Komşu (K-Nearest Neighbors **KNN**)**
# KNN, makine öğrenimi alanında sınıflandırma ve regresyon problemlerini çözmek içiçn kullanılan basit ve popüler bir algoritmadır.
# Temelde, bir veri noktasının sınıfını tahmin etmek veya bir değeri öngörmek için en yakın komşularının etrafındaki veri noktalarının etiketlerini veya değerlerini kullanır.
#
# ![KNN](https://trendspider.com/learning-center/wp-content/uploads/2024/08/K-Nearest-Neighbors-KNN.png)
#
#
#
# ##**KNN Akış Adımları**
# 1. Komşu sayısı K'yı seçin
# 2. K adet komşunun *mesafesini* hesaplayın
#
#     - Euclidean Distance
#     - Manhattan Distance
#     - Minkowski Distance
#     - Hammig Distance
# 3. Hesaplanan mesafelere göre K en yakın komşuyu seçin
# 4. Bu K komşulardan her kategorideki veri noktalarının sayısını sayın
# 5. Yeni veri noktalarını, komşu sayısı maksimum olan kategoriye atayın.
#
#
# ##**Hiperparametre Optimizasyonu**
# Elbow method, KNN gibi kümeleme veya sınıflandırma algoritmalarında K (komşu sayısı) değerini seçmek için kullanılan bir tekniktir.
# Bu yöntem, farklı K değerlerini deneyerek modelin performansını değerlendirir ve optimum K değerini belirlemeye çalışır.
# Elbow methodu, K değerinin artmasıyla birlikte modelin performansındaki azalışın hızının azalması ve eğrinin dirsek gibi bükülmesi prensibine dayanır.
#
# ![HP](https://miro.medium.com/v2/resize:fit:720/format:webp/1*fMgkZHH3n_-FkDa_UyKN2Q.png)
#
#
# ##**Uygulama Alanları**
# - Sağlık: Örneğin kalp krizi riskini tahmin
# - E-ticaret: Kullanıcıların geçmiş alışverişlerine dayanarak ürün önerileri sunma
# - Finans: Banka müşterisinin kredi başvurusu değerlendirmesi
#
#
#
# ##**Zayıf ve Güçlü Yönleri**
# - **Avantajları**
#   - Basitlik ve Doğruluk
#   - Parametre Ayarının Kolaylığı
#   - Örnek Bazlı Öğrenme
#
# - **Dezavantaj**
#   - Boyutluluk Problemi
#   - Veriye Duyarlılık
#   - Yüksek Hesaplama Maliyeti
#
#
# **!** KNN her ne kadar makine öğrenmesi algoritmalarından bir tanesi olsada doğrudan bir eğitim aşaması sözkonusu değildir. Veriye bakarak karar verir.
#
#
# ##**Karar Ağaçları (Decision Trees)**
# Karar ağaçları, ağaç yapısı şeklindeki bir dizi karar kuraloyla veri kümesini bölerek hedef değişkenin tahmin edilmesini sağlar.
# Karar Ağaçları, hem sınıflandırma hem de regresyon problemlerinde kullanılan denetimli (supervised) bir makine öğrenmesi algoritmasıdır.
# Veriyi, “evet/hayır”, “doğru/yanlış” gibi kararlarla dallara ayırır ve sonunda bir tahmin sonucu verir.
#
# **Temel Yapı**:
#
# **Kök düğüm (Root Node)**: Karar ağacının başladığı noktadır. En iyi ayrım yapan özelliktir.
#
# **Dahili düğümler (Internal Nodes)**: Özelliklere göre kararların verildiği ara noktalardır.
#
# **Yaprak düğümler (Leaf Nodes)**: Karar sonucunun çıktığı sınıf veya değerlerdir.
#
#
# ![DT](https://miro.medium.com/v2/resize:fit:1200/1*kwCh2-U02xf-EWaTt3Xr4w.png)
#
#
# ##**Karar Ağaçları Türleri**
# - ID3 (Iterative Dichotomiser 3)
#   - Bu algoritma, aday bölmeleri değerlendirmek için entropi ve bilgi kazancını kullanır.
# -C4.5
#   - ID3'ün daha sonraki versiyonu olarak kabul edilir.
#   - Karar ağaçlarında bölme noktalarını değerlendirmek için bilgi kazancı veya kazanç oranlarını kullanabilir.
# -CART (Sınıflandırma ve regresyon ağaçları)
#   - Bu algoritma genellikle ideal bölünme özelliğini belirlemek için Gini karışıklığını kullanır.
#   - Gini karışıklığı, rastgele seçilen bir özelliğin ne sıklıkla yanlış sınıflandırıldığını ölçer.
#   - Giiş karışıklığını kullanarak değerlendirirken, daha düşük bir değer daha idealdir.
#
#
# ![DT Karşılaştırma](https://miro.medium.com/v2/resize:fit:1316/1*ybrMbCXUTDz0icyck8C4rg.png)
#
#
# ##**ID3 Algoritması (Iterative Dichotomiser 3) Nedir?**
#
# **ID3**, bir **karar ağacı algoritmasıdır**. Veriyi sınıflara ayırmak için en iyi özelliği seçer ve veriyi dallara ayırarak karar ağacı oluşturur.
# Özellikle **sınıflandırma** problemlerinde kullanılır.
#
#
# ##**Nasıl Çalışır?**
#
# 1. Tüm veri seti analiz edilir.
# 2. Her özelliğin (feature) **Bilgi Kazancı (Information Gain)** hesaplanır.
# 3. **En yüksek bilgi kazancı** hangi özellikteyse, ağaç o özellikle dallanmaya başlar.
# 4. Her dal için aynı işlem **özyinelemeli (recursive)** olarak devam eder.
# 5. Tüm veriler sınıflandırıldığında **yaprak düğümler (leaf nodes)** oluşturulur.
#
#
#
# ##**Bilgi Kazancı (Information Gain)**
#
# ID3, veriyi sınıflara ayırırken **bilgi kazancı** kullanır.
#
# ###**Entropi Formülü**
# Entropi, karar ağaçları içinde belirli bir düğümdeki veri noktalarının sınıflarının ne kadar karışık olduğunu ölçen bir metriktir. Karışıklık, karmaşıklık olarak ifade edilebilir.
# Entropi değeri düşük ise düğümün homojen sınıflara hahip olduğunu yani veri noktalarının çoğğunun aynı sınıflara ait olduğunu gösterir.
# Entropi değeri yüksek ise, bir düğümün daha karışık sınıflara sahip olduğunu, yani veri noktalarının farklı sınıflara daha eşit olarak dağıldığını gösterir.
# Entropi 0 ve 1 arasında değer alır. 1' yaklaştıkça entropi (karmaşıklık) artar bu istenilen bir durum değildir.
#
#
# ![Entropy](https://miro.medium.com/v2/resize:fit:1400/1*i7cfMirN2WpaJhYZa1a1Mg.png)
#
#
# \[
# Entropy(S) = - \sum p_i \log_2(p_i)
# \]
#
# - \(S\): veri kümesi
# - \(p_i\): her sınıfın olasılığı
#
# ###**Bilgi Kazancı Formülü**
#
# \[
# IG(S, A) = Entropy(S) - \sum \left(\frac{|S_v|}{|S|} \cdot Entropy(S_v)\right)
# \]
#
# - \(A\): ayırmak için seçilen özellik
# - \(S_v\): A özelliğine göre oluşan alt küme
#
#
# ![Gain](https://spicerrobots.com/wp-content/uploads/2012/01/decision-tree-equations.png)
#
#
#
# ##**CART (Classification and Regression Trees) Nedir?**
#
# **CART (Classification and Regression Trees)**, hem **sınıflandırma** hem de **regresyon** problemlerinde kullanılan güçlü bir **karar ağacı algoritmasıdır**.
#
# - **Sınıflandırma** problemlerinde sınıf tahmini yapar.
# - **Regresyon** problemlerinde sürekli (numerik) değer tahmini yapar.
#
#
# ##**Temel Özellikler**
#
# - Ağaç **ikili (binary tree)** şeklindedir.
#   Yani her düğüm en fazla **2 dala** ayrılır (Evet / Hayır gibi).
# - Veri, dallara ayrılırken en iyi ayıran özellik ve eşik değeri seçilir.
# - Her dal, veri kümesini bir alt kümeye böler.
# - Ağaç, belirli bir durma koşuluna kadar büyür (örneğin: minimum örnek sayısı, maksimum derinlik).
#
#
#
# ##**Bölme Kriteri: Gini İndeksi**
# CART, veriyi bölerken **Gini İndeksi** kullanır.
# Bir düğümdeki veri noktalarının farklı sınıflara dağılımının ne kadar karışık olduğunu ölçer.
# Gini karışıklığı 0 ile 0.5 arasında bir değer alır. 0, en saf durumu (yani tüm veri noktalarının aynı sınıfa ait olduğu durumu), 0.5 ise en karışık durumu ifade eder.
# Bir düğümün Gini karışıklığı ne kadar düşükse, o kadar homojen sınıflara sahip olur ve böylece daha iyi bir bölünme kriteri olarak kabul edilir.
#
#
#
# ###**Gini İndeksi Formülü:**
# **Gini Impurity** (Gini belirsizliği), bir başka CART tarafından kullanılan bir ölçümdür.
#
# ![Gini Impurity](https://favtutor.com/resources/images/uploads/gini_impurity_decision_tree1.png)
#
#
#
# \[
# Gini(S) = 1 - \sum p_i^2
# \]
#
# - \(S\): veri kümesi
# - \(p_i\): sınıf \(i\)'nin örnekler içindeki oranı
#
# **Gini değeri düşükse**, kümeler daha saf (homojen) demektir.
#
#
# ## 🧮 Örnek: Sınıflandırma
#
# | Yaş | Gelir | Ev Sahibi? | Kredi Verilsin mi? |
# |-----|-------|-------------|--------------------|
# | 25  | Düşük | Hayır       | Hayır              |
# | 40  | Yüksek| Evet        | Evet               |
# | 35  | Orta  | Hayır       | Evet               |
# | 28  | Orta  | Evet        | Hayır              |
#
# CART şu şekilde çalışır:
#
# 1. Tüm özellikler için olası **bölme noktaları** belirlenir (örneğin Yaş < 30?).
# 2. Her bölmenin Gini değeri hesaplanır.
# 3. En düşük Gini değerine sahip bölme seçilir.
# 4. Veri ikiye ayrılır → sol ve sağ dal.
# 5. Aynı işlem her dalda **özyinelemeli** olarak devam eder.
#
#
#
# ##**CART ile Regresyon**
#
# Sınıflandırmadan farklı olarak:
# - Hedef değişken **sürekli bir sayı** olur.
# - Gini yerine **varyans (variance)** veya **ortalama karesel hata (MSE)** gibi ölçütler kullanılır.
#
#
#
# ##**Avantajları**
#
# - Hem sınıflandırma hem regresyon için uygundur.
# - Sayısal ve kategorik verilerle çalışabilir.
# - Sonuçları görselleştirmek ve yorumlamak kolaydır.
# - **Özellik ölçeklemesine** (standartlaştırma) gerek duymaz.
#
#
#
# ##**Dezavantajları**
#
# - **Aşırı öğrenme (overfitting)** riski vardır.
# - Küçük veri değişikliklerine karşı hassastır.
# - Derin ağaçlar yorumlanması zor modeller üretebilir.
#
#
#
# ##**CART vs ID3 vs C4.5**
#
# | Özellik          | CART                      | ID3                    | C4.5                       |
# |------------------|---------------------------|-------------------------|----------------------------|
# | Bölme Ölçütü     | Gini İndeksi / Varyans    | Bilgi Kazancı           | Gain Ratio + Bilgi Kazancı |
# | Ağaç Yapısı      | İkili (binary)            | Çok dallı               | Çok dallı                  |
# | Kullanım Alanı   | Sınıflandırma + Regresyon | Sadece sınıflandırma    | Sadece sınıflandırma       |
# | Sayısal Veri     | Doğrudan desteklenir      | Önce kategorize edilmeli| Doğrudan desteklenir       |
#
#
#
# ##**Not**
#
# CART, birçok modern algoritmanın (örneğin **Random Forest**, **XGBoost**) temelini oluşturur.
# Veriyi ikiye bölerek basit ama etkili modeller üretir.
#
#
#
# ##**Karar Ağaçları Parametreleri**
# - **Maksimum Derinlik (max_depth)**: Ağacın izin verilen maksimum derinliği. Yani kökten yapraklara kadar kaç seviyeye kadar inebilir? Eğer çok yüksek ayarlanırsa ağaç aşırı uyum yapabilir (overfitting); çok düşük olursa yetersiz öğrenir (underfitting).
# - **Mininmum Bölme Boyutu (min_samples_split)**: Bir düğüm (node) bölünmeden önce sahip olması gereken en az örnek sayısı. Eğer node’daki örnek sayısı bu değerin altındaysa, o düğüm artık bölünmez, yaprak olur. Bu parametre çok küçük ayarlanırsa ağaç çok dallanabilir, çok büyük olursa ağaç çok sade kalabilir.
# - **Minimum Yaprak Boyutu (min_samples_leaf)**:Bir yaprak (leaf) düğümünde olması gereken en az örnek sayısı. Bir bölünme gerçekleştiğinde, her iki alt düğümde de bu sayıya ulaşılmalı; yoksa o bölünme geçersiz sayılır. Böylece çok küçük yapraklar oluşması engellenir.
# - **Maksimum Özellikler (max_features)**: Her bölünme kararında, split (ayırma) için incelenecek özelliklerin (features) maksimum sayısını belirler. Örneğin veri setinde 20 özellik varsa ama max_features = 5 ise her düğüm bölünürken rastgele seçilen 5 özellik üzerinden değerlendirme yapılır. Bu, hesaplama maliyetini düşürür ve ağaçların genelleme kabiliyetini artırabilir.
# - **Bölünme Kriteri (criterion)**: Bir düğümde hangi ölçütle en iyi bölünmenin seçileceğini belirler. Sınıflandırma için yaygın kriterler gini (Gini safsızlığı) veya entropy (bilgi kazancı) dir. Regresyon ağaçlarında farklı kriterler olabilir.
# - Bu hiperparametrelerin ayarlanması için kapsamlı arama ve çapraz doğrulama gibi yöntemler kullanılmaktadır.
#
#
# #**Rastgele ormanlar (Random Forest)**
# Rasgele ormanlar, birden çok karar ağacının bir araya gelerek bir orman oluşturduğu bit topluluk öğrenme (ensemble learning) yötemidir.
# Her karar ağacı, farklı bir alt örneklem (bootstrap sample) ve/veya alt özellikler (random subset of features) kullanılarak eğitilir.
#
#
# ![Random Forest](https://cdn.analyticsvidhya.com/wp-content/uploads/2024/10/5.webp)
#
#
# ##**Rasgele Orman Türleri**
# - Sınıflandırma için Ragele Ormanlar
# - Regresyon için Rasgele Ormanlar
#
#
#
# ![RF](https://eol.pages.cms.hu-berlin.de/geo_rs/fig/s09_rf-concept.png)
#
#
#
# ##**Ragele Orman Hiperparametreleri**
# - Ağaç Sayısı (n_estimators)
# - Özniteliklerin Sayısı (max_features)
# - Ağaç Derinliği (max_depth)
# - Örnekleme Oranı (bootstrap)
#
#
# ##**Güçlü Yönleri**
#
# - **Overfitting’e karşı dayanıklı:**
#   Birçok karar ağacı birlikte çalıştığı için tek bir ağacın yaptığı aşırı öğrenme (overfitting) azaltılır.
#
# - **Yüksek doğruluk sağlar:**
#   Özellikle klasik makine öğrenmesi yöntemleriyle karşılaştırıldığında genellikle daha başarılı sonuçlar verir.
#
# - **Sınıflandırma ve regresyon için uygundur:**
#   Hem kategorik hem de sayısal verilerle çalışabilir.
#
# - **Feature importance (özellik önemi) sunar:**
#   Hangi değişkenlerin modele ne kadar katkı sağladığını görebilirsin.
#
# - **Eksik verilerle başa çıkabilir:**
#   Bazı eksik değerler olsa bile model genel olarak sağlam çalışabilir.
#
# - **Paralel çalışmaya uygundur:**
#   Her ağaç bağımsız olduğu için eğitim işlemi çok çekirdekli sistemlerde hızlandırılabilir.
#
#
# ##**Zayıf Yönleri**
#
# - **Yorumlaması zordur:**
#   Tek bir karar ağacı gibi görselleştirilemediği için modelin neden o sonucu verdiğini anlamak zordur.
#
# - **Tahmin süresi uzundur:**
#   Çok sayıda ağaç olduğunda, tahmin yapmak daha yavaş olabilir.
#
# - **Kaynak tüketimi fazladır:**
#   RAM ve işlem gücü kullanımı yüksektir, özellikle büyük veri setlerinde.
#
# - **Gerçek zamanlı uygulamalar için uygun olmayabilir:**
#   Anlık tepki gerektiren sistemlerde yavaş kalabilir.
#
# - **Dengesiz veri setlerinde performans düşebilir:**
#   Azınlık sınıf (rare class) yeterince iyi öğrenilemeyebilir, ek dengeleme teknikleri gerekebilir.
#
#
# #**Lojistik Regresyon (Logistic Regression)**
# - Lojistik regresyon, istatistik ve makine öğrenmesi alanlarında sınıflandırma problemlerini çözmek için kullanılan bir yöntemdir.
# - Genellikle bağımlı değişkenin kategorik olduğu durumlarda kullanılır.
# - Örneğin, bir müşterinin bir ürünü satın alıp almama olasılığını tahmin etmek gibi durumlarda kullanılır.
#
#
#
# ##**Lojistik Regresyon Tahmini**
# - **İleri Yayılım (Forward Propagation)**: Lojistik regresyon modelinde girdi verilerinin modelden geçip tahmin (çıktı) üretmesine kadar olan süreçtir. Yani, girdilerden başlayarak ağırlıklarla çarpılır, aktivasyon fonksiyonundan geçirilir ve nihai tahmin elde edilir.
# - Aşamaları:
#   - Lineer Kombinasyon (Z hesaplama)
#   - Sigmoid Aktivasyon (Tahminin hesaplanması)
#   -Çıktının Üretilmesi
#
#
#
# ##**Lojistik Regresyon Eğitimi**
# - **Ağırlık ve Biasların başlatılması**
# - **İleri Yayılım (Forward Propagation)**: Giriş verilerinin modelden geçerek bir tahmin (olasılık) üretmesi sürecidir. Lojistik regresyonda bu işlem, doğrusal hesaplamalar ve sigmoid aktivasyon fonksiyonu kullanılarak yapılır.Forward propagation, modelin mevcut ağırlıklarla tahmin üretmesini sağlar. Bu tahmin, daha sonra **kayıp (loss)** hesaplamasında ve **geri yayılım (backpropagation)** sırasında ağırlıkları güncellemek için kullanılır.
#   - Aşamaları:
#     - Lineer Hesaplama (Z değeri)
#     - Sigmoid Aktivasyon (Tahminin Üretilmesi)
#     - Tahminin Yorumu
#
# - **Loss Fonksiyonunun Hesaplanması**: Kayıp fonksiyonu, modelin ne kadar “yanıldığını” sayısal olarak ifade eder.
# Bu değer, **geri yayılım (backpropagation)** sırasında ağırlıkları güncellemek için kullanılır.
# Amaç: **Kayıp fonksiyonunu minimize etmek**, yani modelin hatalarını en aza indirmek.
#
# - **Geri Yayılım (Backward Propagation)**: Loss fonksiyonunun weightlere ve biasa göre türevlerini bulmak.
#
# - **Ağırlıkların Güncellenmesi**
#
#
#
# ##**Lojistik Regresyon Hiperparametreleri**
# - **Penalty (cezalandırma)**
# - **C (cezalandırma katsayısı)**
# - **Solver (çözücü)**
# - **Max Iterations**
# - **Class weight (sınıf ağırlığı)**
#
# ## **Logistic Regression: Avantajlar ve Dezavantajlar**
#
# ####  **Avantajları**
# - Basit, hızlı ve uygulanması kolaydır.
# - Olasılık tahmini yapabilir (sadece sınıf değil, güven oranı da verir).
# - Model katsayıları yorumlanabilir (hangi değişkenin etkisi ne kadar).
# - Küçük veri kümelerinde ve doğrusal ilişkilerde iyi performans gösterir.
# - Overfitting riski, regularization (L1/L2) ile azaltılabilir.
#
# ####  **Dezavantajları**
# - Sadece **doğrusal ayrılabilen** verilerde iyi çalışır.
# - Karmaşık, doğrusal olmayan ilişkileri öğrenemez.
# - Outlier (aykırı değerler) sonuçları olumsuz etkileyebilir.
# - Büyük özellik sayısında (high dimensional data) performansı düşebilir.
# - Doğru sınıflandırma için veri ölçeklendirmesi (scaling) gerekebilir.
#
#
# > **Özetle:** Logistic Regression basit ve yorumlanabilir bir modeldir,
# > ancak karmaşık veya doğrusal olmayan veri yapılarında yetersiz kalabilir.
#
#
# #**Destek Vektör Makineleri (Support Vector Machines)**
# - SVM, sınıflandırma ve regresyon problemlerini çözmek için kullanılan güçlü bir makine öğrenimi algoritmasıdır.
# - SVM, veri kkümesini sınıflar arasında en iyi şekilde ayıran bir hiperdüzlemi bulmaya çalışır.
# - SVM, özellikle doğrusal olmayan veri kümeleri için etkilidir. Çünkü kernel yöntemi kullanarak veriyi daha yüksek boyutlu uzaylara dönüştürerek doğrusal olarak ayrılabilir bir yapı elde edebilir.
#
# ![SVM](https://i0.wp.com/spotintelligence.com/wp-content/uploads/2024/05/decision-margin-svm.jpg?resize=1024%2C576&ssl=1)
#
#
# ##**SVM Hipermatreleri**
# - **C**: C hiperparametresi, modelin eğitim verisindeki hataları tolere etme derecesini kontrol eder. Yani, doğruluk (overfitting riski) ile genelleme (underfitting riski) arasındaki dengeyi belirler.
#   - Eğer C küçükse → SVM bazı noktaların yanlış sınıflanmasına izin verir ama karar sınırı daha düzgün olur.
#   - Eğer C büyükse → Model, her noktayı doğru sınıflamaya çalışır, karar sınırı “kıvrımlı” ve veriye aşırı uyumlu olabilir.
#
# - **Kernel(çekirdek) Tipi**: SVM, temelde doğrusal bir ayırıcı sınır (hyperplane) bulmaya çalışır.
# Ama birçok veri seti doğrusal olarak ayrılamaz (örneğin, daire şeklinde ayrılmış iki sınıf).
# İşte burada kernel trick (çekirdek numarası) devreye girer.
#
# Kernel, veriyi yüksek boyutlara taşımadan, o boyutlarda nokta çarpımını (benzerliği) hesaplamamıza izin verir.
# Böylece doğrusal olmayan sınırlar öğrenilebilir.
#   - Veri doğrusal ayrılabiliyorsa: linear
#   - Veri karmaşıksa, doğrusal değilse: rbf (genellikle varsayılan)
#   - Veriler arasında polinom ilişkiler varsa: poly
#   - Sinir ağı benzeri davranış isteniyorsa: sigmoid (nadiren kullanılır)
#
# ##**Zayıf Yönler**
# - Veriseti çok büyükse aşırı uydurmaya eğilimli olabilir.
#
# ##**Güçlü Yönler**
# - Doğrusal ve doğrusal olmayan sınıflandırma problemlerinde etkilidir.
#
#
# #**Naive Bayes**
# - Naive Bayes, makine öğrenmesinde sınıflandırma ve olasılıklı tahminler yapmak için kullanılan olasılıksal bir yöntemdir.
# - Temel olraka Bayes teorremi prensibine dyanır ve "naive" (saf) adını, sınıf etiketlerinin birbirinden bağımsız olduğunu varsayan basit bir varsayıma dayanır.
#
# ![BAYES](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsGSQkUeqc2aS1pPhZz335YW6iUlQ9xbR5pQ&s)
#
# ![](https://aihubprojects.com/wp-content/uploads/2020/07/D23IQIdXcAE2egn.jpg)
#
# ##**Güçlü Yönler (Advantages)**
#
# - Basit ve hızlıdır, eğitim süresi çok kısadır.
# - Küçük veri setlerinde bile iyi performans gösterir.
# - Yüksek boyutlu veri (çok sayıda özellik) ile iyi çalışır.
# - Metin sınıflandırma (spam tespiti, duygu analizi) gibi uygulamalarda çok etkilidir.
# - Overfitting riski düşüktür.
# - Olasılıksal tahmin yapar, sınıfların olasılıklarını hesaplayabilir.
#
# ##**Zayıf Yönler (Disadvantages)**
#
# - Özellikler arasında bağımsızlık varsayımı yapar; bu çoğu gerçek veri için yanlış olabilir.
#
# Özellikler birbirine güçlü şekilde bağlıysa performansı düşer.
# - Sıfır frekans problemi olabilir (bir sınıfta gözlenmeyen bir özellik olursa).
# - Karmaşık ilişkileri öğrenemez, doğrusal olmayan sınırlarda zayıftır.
# - Çok küçük veri setlerinde bazı olasılık tahminleri güvenilmez olabilir.
#
#
# #**Lineer Regresyon**
# - Lineer Regresyon, iki veya daha fazla değişken arasındaki ilişkiyi modellemek için kullanılan istatistiksel bir yöntemdir.
# - Özellikle, bağımsız değişkenlerin (genellikle X olarak adlandırılır) bağımlı değişkene (genellikle y olarak adlandırılır) olan etkisini tahmin etmek için kuallanılır.
#
# ![LR](http://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRxKB_NdRflrEqXGZTlNQ7IFOwAN1HlKacseg&s)
#
#
# ##**Lineer Regresyon Türleri**
# - **Basit Lineer Regresyon**: *y=ax+b*
# - **Çoklu Lineer Regresyon**: *y=ax1+bx2+cx3+b*
# - **Polinomsal Regresyon**: *y=b+ax1+cx^2+dx^3*
# - **Ridge ve Lasso Regresyonu**: *Overfittingi azaltmak için kullanılır. Katsayıları sıfırlar.*
#
#
# ##**Zayıf ve Güçlü Yönleri**
# **Zayıf Yönler**
# - Doğrusal olmayan ilişkileri yakalamakta zorlanabilir.
# - Outlier hassasiyeti
#
#
# **Güçlü Yönler**
# - Basit ve anlaşılır modelleme. Yüksek yorumlanabilirlik.
# - Kısa eğitim süresi
#
#
# # **Multiple Linear Regression (Çoklu Lineer Regresyon)**
#
# Çoklu lineer regresyon, bir bağımlı değişkeni birden fazla bağımsız değişken ile modellemeye yarayan istatistiksel bir yöntemdir.
#
# ## **Temel Kavramlar**
#
# - **Hedef değişken (Dependent variable):** Tahmin etmek istediğimiz değişken (y).
# - **Bağımsız değişkenler (Independent variables):** Hedef değişkeni açıklayan değişkenler (x₁, x₂, ..., xₙ).
# - **Katsayılar (Coefficients):** Her bağımsız değişkenin hedef değişken üzerindeki etkisini gösterir (β₁, β₂, ..., βₙ).
# - **Sabit terim (Intercept):** Tüm bağımsız değişkenler sıfır olduğunda hedef değişkenin değeri (β₀).
#
# ## **Model Denklemi**
#
# Matematiksel olarak:
# y = β₀ + β₁x₁ + β₂x₂ + ... + βₙxₙ + ε
#
# - ε → hata terimi, modelin açıklayamadığı kısmı temsil eder.
#
# ## **Varsayımlar**
#
# 1. Hedef değişken ile bağımsız değişkenler arasında lineer ilişki vardır.
# 2. Hata terimleri birbirinden bağımsızdır.
# 3. Hata terimleri normal dağılım gösterir.
# 4. Çoklu doğrusal bağlantı (multicollinearity) minimumdur.
#
# ## **Kullanım Alanları**
#
# - Ev fiyat tahmini (farklı özelliklere göre)
# - Maaş tahmini (deneyim, eğitim, şehir vs.)
# - Pazarlama verisi analizi (reklam harcaması, ürün fiyatı, satış)
#
#
# # **Polynomial Regression (Polinom Regresyonu)*
#
# Polinom regresyon, bağımlı ve bağımsız değişkenler arasındaki **lineer olmayan ilişkileri modellemek** için kullanılan bir regresyon yöntemidir.
#
# ## **Temel Kavramlar**
#
# - Lineer regresyonun genişletilmiş halidir.
# - Bağımsız değişkenin kuvvetleri (x², x³, ...) modele eklenerek non-lineer ilişkiler yakalanır.
# - Model hala katsayılar üzerinden çalışır, yani lineer regresyon yöntemleriyle çözülür.
#
# ## **Model Denklemi (2. derece örnek)**
#
# y = β₀ + β₁x + β₂x² + ε
#
# - x² → polinom terimi, x ile y arasındaki eğriliği yakalar.
# - Daha yüksek dereceler kullanılarak daha karmaşık ilişkiler modellenebilir.
#
# ## **Avantajları**
#
# - Lineer regresyonun sınırlamalarını aşar.
# - Veri setindeki eğrisel ilişkileri yakalayabilir.
#
# ## **Dezavantajları**
#
# - Çok yüksek derece polinom overfitting riskini artırır.
# - Model yorumlaması lineer regresyona göre daha karmaşıktır.
#
# ## **Kullanım Alanları**
#
# - Fizik ve mühendislikte eğrisel veri analizi
# - Satış tahmini ve trend analizleri
# - Ekonomik verilerde büyüme veya düşüş trendlerinin modellenmesi
